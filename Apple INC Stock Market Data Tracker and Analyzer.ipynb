# %% [markdown]
# # **Stock Market Data Tracker and Analyzer Project**
# Assignment Information
#
# *   **Name of Assignment:**Stock Market Data Tracker and Analyzer Project
# *   **Course:** CSCI 610: Programming for Data Science
# *   **Instructor:** Rachit Kapoor
# *   **Company:** Apple Inc

# %% [markdown]
# **Short Term:** 20 days

# %%
#Import the finance package
import yfinance as yf
#import the matplotlib library for plotting
import matplotlib.pyplot as plt

#Define the ticker symbol for the stock to analyze
ticker_symbol = "AAPL"
#Access stock information for the ticker
print("Apple Inc Stock Data for 20 days - short term")
stock_data = yf.Ticker(ticker_symbol)
# Retrieve historical data for the stock
# Retrieve historical data for 20 days
start_date = "2024-02-01"
end_date = "2024-02-20"

hist_data = stock_data.history(start=start_date, end=end_date)
#Display the first few rows to understand the data structure
display(hist_data)
#calculate the daily returns, which is the percentage charge in closing price day-over-day
hist_data["Daily Return"] = hist_data['Close'].pct_change()
# Out:
# Apple Inc Stock Data for 20 days - short term
#                                  Open        High         Low       Close  \
# Date
# 2024-02-01 00:00:00-05:00  183.755534  186.711754  183.585753  186.621872
# 2024-02-02 00:00:00-05:00  179.630787  187.091269  179.021564  185.613159
# 2024-02-05 00:00:00-05:00  187.910213  189.008818  185.603160  187.440811
# 2024-02-06 00:00:00-05:00  186.621869  189.068743  186.531987  189.058762
# 2024-02-07 00:00:00-05:00  190.397053  190.806534  188.369641  189.168625
# 2024-02-08 00:00:00-05:00  189.148646  189.298448  187.111252  188.080017
# 2024-02-09 00:00:00-05:00  188.649994  189.990005  188.000000  188.850006
# 2024-02-12 00:00:00-05:00  188.419998  188.669998  186.789993  187.149994
# 2024-02-13 00:00:00-05:00  185.770004  186.210007  183.509995  185.039993
# 2024-02-14 00:00:00-05:00  185.320007  185.529999  182.440002  184.149994
# 2024-02-15 00:00:00-05:00  183.550003  184.490005  181.350006  183.860001
# ...

# %%
#Ensure plots displayed inline in the notebook
# %matplotlib inline

#Plot the closing price of the stock
plt.figure(figsize=(20,5))
plt.plot((hist_data['Close']), label = 'Apple Inc close price, Short-term 20 days')
plt.title("Closing price over time")
plt.xlabel('Data')
plt.ylabel('Closing Price USD ($)')
plt.legend()

#calculate the maximum closing price and print it
max_price_date = hist_data['Close'].idxmax()
max_price = hist_data['Close'].max()
print(f"Maximum closing price: {max_price:.2f}")

#calculate the minimum closing price and print it
min_price_date = hist_data['Close'].idxmin()
min_price = hist_data['Close'].min()
print(f"Minimum closing price: {min_price:.2f}")

plt.scatter(min_price_date, min_price, color='red', label=f'Min Price: ${min_price:.2f}')
plt.scatter(max_price_date, max_price, color='red', label=f'Max Price: ${max_price:.2f}')

plt.annotate(f'Min Price: ${min_price:.2f}', (min_price_date, min_price), xytext=(-50, 30), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", color='blue'))
plt.annotate(f'Max Price: ${max_price:.2f}', (max_price_date, max_price), xytext=(-50, -30), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", color='green'))

plt.grid(True)
plt.show()
# Out:
# Maximum closing price: 189.17
# Minimum closing price: 182.31

# %%
#Calculate the percentage change from the first to the last clsoing price in the period
percentage_change = ((hist_data['Close'][-1] - hist_data['Close'][0]) / hist_data['Close'][0]) * 100
print(f"Apple Inc 20 days percentage change in closing price {percentage_change:.2f}%")
# Out:
# Apple Inc 20 days percentage change in closing price -2.31%

# %% [markdown]
# **Long Term:** 2 month

# %%
#Define the ticker symbol for the stock to analyze
ticker_symbol = "AAPL"
#Access stock information for the ticker
print("Apple Inc Stock Data for 2 month - Long time")
stock_data = yf.Ticker(ticker_symbol)
# Retrieve historical data for the stock
# Retrieve historical data for 2 month
hist_data = stock_data.history(period="2mo")
#Display the first few rows to understand the data structure
display(hist_data)
#calculate the daily returns, which is the percentage charge in closing price day-over-day
hist_data["Daily Return"] = hist_data['Close'].pct_change()
# Out:
# Apple Inc Stock Data for 2 month - Long time
#                                  Open        High         Low       Close  \
# Date
# 2024-01-09 00:00:00-05:00  183.685606  184.914035  182.497120  184.904053
# 2024-01-10 00:00:00-05:00  184.115062  186.162437  183.685602  185.952713
# 2024-01-11 00:00:00-05:00  186.302271  186.811631  183.385994  185.353485
# 2024-01-12 00:00:00-05:00  185.822881  186.502022  184.953994  185.683060
# 2024-01-16 00:00:00-05:00  181.927853  184.025168  180.699410  183.395981
# 2024-01-17 00:00:00-05:00  181.038998  182.696871  180.070233  182.447189
# 2024-01-18 00:00:00-05:00  185.852846  188.898962  185.593183  188.389618
# 2024-01-19 00:00:00-05:00  189.088718  191.705375  188.579374  191.315872
# 2024-01-22 00:00:00-05:00  192.054929  195.081066  192.014971  193.642899
# 2024-01-23 00:00:00-05:00  194.771475  195.500540  193.582989  194.931259
# 2024-01-24 00:00:00-05:00  195.170947  196.129730  194.092321  194.252121
# ...

# %%
#Ensure plots displayed inline in the notebook
# %matplotlib inline

#Plot the closing price of the stock
plt.figure(figsize=(20,5))
plt.plot((hist_data['Close']), label = 'Apple Inc close price, Long Term - 2 month')
plt.title("Closing price over time")
plt.xlabel('Data')
plt.ylabel('Closing Price USD ($)')
plt.legend()

#calculate the maximum closing price and print it
max_price_date = hist_data['Close'].idxmax()
max_price = hist_data['Close'].max()
print(f"Maximum closing price: {max_price:.2f}")

#calculate the minimum closing price and print it
min_price_date = hist_data['Close'].idxmin()
min_price = hist_data['Close'].min()
print(f"Minimum closing price: {min_price:.2f}")

plt.scatter(min_price_date, min_price, color='red', label=f'Min Price: ${min_price:.2f}')
plt.scatter(max_price_date, max_price, color='red', label=f'Max Price: ${max_price:.2f}')

plt.annotate(f'Min Price: ${min_price:.2f}', (min_price_date, min_price), xytext=(-50, 30), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", color='blue'))
plt.annotate(f'Max Price: ${max_price:.2f}', (max_price_date, max_price), xytext=(-50, -30), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", color='green'))

plt.grid(True)
plt.show()
# Out:
# Maximum closing price: 194.93
# Minimum closing price: 169.00

# %%
#Calculate the percentage change from the first to the last clsoing price in the period
percentage_change = ((hist_data['Close'][-1] - hist_data['Close'][0]) / hist_data['Close'][0]) * 100
print(f"Apple Inc 2 Month percentage change in closing price {percentage_change:.2f}%")
# Out:
# Apple Inc 2 Month percentage change in closing price -7.67%
